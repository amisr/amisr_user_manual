# %%
import visuamisr
import datetime as dt

# %% [markdown]
# # Original File Format

# %%
filename = '/Users/leslie/Desktop/Data/AMISR/PFISR/2020/20200324.010_ac_10min-fitcal_py3_geolib.h5'
isr = visuamisr.Analyze(filename)
isr.plot_polar_beam_pattern(min_elevation=10)
# Out:
# /Users/leslie/Desktop/Projects/AMISR/visuamisr/visuamisr/analyze.py:341: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
isr.rti(['density','Te','Ti','velocity'],
        time_lim=[dt.datetime(2020,3,24,0,0),dt.datetime(2020,3,25,0,0)],
        ylim=[100,500],bmnum=1)
# Out:
# /Users/leslie/Desktop/Projects/AMISR/visuamisr/visuamisr/analyze.py:564: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # New File Format

# %%
filename = '/Users/leslie/Desktop/Data/AMISR/PFISR/2020/20200324.010_ac_10min-fitcal_apexpy.h5'
isr = visuamisr.Analyze(filename)
isr.plot_polar_beam_pattern(min_elevation=10)
# Out:
# /Users/leslie/Desktop/Projects/AMISR/visuamisr/visuamisr/analyze.py:341: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
isr.rti(['density','Te','Ti','velocity'],
        time_lim=[dt.datetime(2020,3,24,0,0),dt.datetime(2020,3,25,0,0)],
        ylim=[100,500],bmnum=1)
# Out:
# /Users/leslie/Desktop/Projects/AMISR/visuamisr/visuamisr/analyze.py:564: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
